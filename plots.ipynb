# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
SNR = [0, 5, 10, 15, 20, 25, 30]
SC_GIR = [85.18, 86.01, 86.37, 86.52, 86.61, 86.67, 86.71]
SEM_RE = [30, 44, 50, 53, 55, 55.5, 55.7]
DeepJSCC = [17, 24, 28, 33.5, 37.5, 39.5, 40]
DeepSC = [0, 11, 20, 25.4, 28, 29.4, 30.2]
BPG_23 = [0,0,0,19.5,63.5,75.5,80.5]

# %%
plt.plot(SNR, SC_GIR, label='SC-GIR', marker='o')
plt.plot(SNR, SEM_RE, label='SEM-RE', marker='^')
plt.plot(SNR, DeepJSCC, label='DeepJSCC', marker='*')
plt.plot(SNR, DeepSC, label='DeepSC', marker='>')
plt.plot(SNR, BPG_23, label='BPG+2/3', marker='v')
plt.xlabel('SNR')
plt.ylabel('Test Accuracy')
plt.grid()
# Out:
# Text(0, 0.5, 'Test Accuracy')
